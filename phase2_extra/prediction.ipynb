# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~
#
# IMPORT PYTHON LIBRARIES
#
# ~~~~~~~~~~~~~~~~~~~

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~
#
# CREATE THE DATAFRAME
#
# ~~~~~~~~~~~~~~~~~~~

# %%
# create a dataframe with the speed_dating dataset:
original_df = pd.read_csv('data/speed_dating.csv')

# create a copy of the dataframe for our analysis:
df = original_df.copy()

# drop the unnamed column, which was a duplicate of the indexes:
df = df.iloc[:, 1:]

# print the dataframe to check the values
df
# Out:
#       match  exphappy  samerace  hobby_diff_phys  hobby_diff_out  \
# 0         0       3.0         0              7.0            21.0
# 1         0       3.0         0              7.0            19.0
# 2         1       3.0         1              9.0            18.0
# 3         1       3.0         0              6.0            14.0
# 4         1       3.0         0              2.0            28.0
# ...     ...       ...       ...              ...             ...
# 8341      0       3.0         0             21.0            21.0
# 8342      0       3.0         0             16.0             7.0
# 8343      0       3.0         0             11.0            26.0
# 8344      0       3.0         0             11.0            16.0
# 8345      0       3.0         0              9.0            15.0
#
#       hobby_diff_in  same_goal  attr_diff  sinc_diff  intel_diff  fun_diff  \
# 0              24.0          0       36.0       23.0        24.0      20.0
# ...

# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~
#
# DEFINE THE DESCRIPTIVE FEATURES & TARGET FEATURE
#
# ~~~~~~~~~~~~~~~~~~~

# %%
# define the continuous features
continuous_features = ['hobby_diff_phys', 'hobby_diff_out', 'hobby_diff_in', 'attr_diff', 'sinc_diff', 'intel_diff', 'amb_diff', 'fun_diff', 'income_diff', 'age_diff', 'confidence'] 

# define the categorical features
categorical_features = ['exphappy', 'samerace', 'same_goal', 'same_career', 'out_freq', 'date_freq', 'imprace'] 

# define the target feature
target_feature = ['match']

# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~
#
# DATA PREPROCESSING - HANDLE MISSING VALUES
#
# ~~~~~~~~~~~~~~~~~~~

# %%
#

# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~
#
# NORMALIZATION
#
# ~~~~~~~~~~~~~~~~~~~

# %%
#

# %% [markdown]
# ~~~~~~~~~~~~~~~~~~~
#
# TRANSFORMATION - EQUIWIDTH
#
# ~~~~~~~~~~~~~~~~~~~

# %%
for con_feature in continuous_features:
    # get the range of the descriptive feature:
    max = df[con_feature].max()
    min = df[con_feature].min()

    # define the number of bins:
    numOfBins = 10

    # define the bin width:
    width = (max-min)/numOfBins

    # create a histogram using equi-width:
    sns.histplot(data=df, x=con_feature, binwidth=width)

    # display histogram
    plt.show()

# %%
# traverse the collection of continuous features:
for con_feature in continuous_features:

    # define the total number of instances:
    total_values = df[con_feature].value_counts().sum()

    # define the number of bins:
    numOfBins = 10

    # calculate the frequency:
    frequency = total_values / numOfBins
    
    # create a histogram using equi-frequency:
    sns.histplot(data=df, x=con_feature, stat='density', bins=numOfBins)

    # display histogram
    plt.show()
